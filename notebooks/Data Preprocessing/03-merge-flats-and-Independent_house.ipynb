# %%
import pandas as pd
import numpy as np

flats = pd.read_csv('A:/CODES/PROJECTS/appartments/data/external/gurgaon/Flats_cleaned.csv')
houses = pd.read_csv('A:/CODES/PROJECTS/appartments/data/external/gurgaon/Independent_house_cleaned.csv')

# %%
df = pd.concat([flats,houses], ignore_index=True)

# %%
# Shuffle the DataFrame to ensure that the rows are in random order after concatenation
df = df.sample(df.shape[0], ignore_index=True)
df.head()
# Out:
#                                    property_name property_type  \
# 0                            2 BHK Flat in Sohna          flat
# 1                4 BHK Flat in Sector 72 Gurgaon          flat
# 2                2 BHK Flat in Sector 79 Gurgaon          flat
# 3  9 Bedroom House for sale in Sector 12 Gurgaon         house
# 4                3 BHK Flat in Sector 90 Gurgaon          flat
#
#                 society  price  price_per_sqft    area  \
# 0         ashiana anmol   0.90          9463.0   951.0
# 1         tata primanti   3.20         12190.0  2625.0
# 2    supertech araville   0.71          5522.0  1286.0
# 3       anamika enclave   6.00         14492.0  4140.0
# 4  shree vardhman flora   0.90          4615.0  1950.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1275(118.45 sq.m.)Carpet a...        2         2
# 1  Super Built up area 2625(243.87 sq.m.)Built Up...        4         4
# ...

# %%
df.to_csv('A:/CODES/PROJECTS/appartments/data/external/gurgaon/properties.csv', index=False)

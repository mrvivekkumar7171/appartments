# %%
import pandas as pd
import numpy as np

flats = pd.read_csv('A:/CODES/PROJECTS/appartments/Data/gurgaon/Flats_cleaned.csv')
houses = pd.read_csv('A:/CODES/PROJECTS/appartments/Data/gurgaon/Independent_house_cleaned.csv')

# %%
df = pd.concat([flats,houses], ignore_index=True)

# %%
# Shuffle the DataFrame to ensure that the rows are in random order after concatenation
df = df.sample(df.shape[0], ignore_index=True)
df.head()
# Out:
#                                   property_name property_type  \
# 0              2 BHK Flat in Sector 107 Gurgaon          flat
# 1               3 BHK Flat in Sector 69 Gurgaon          flat
# 2               3 BHK Flat in Sector 69 Gurgaon          flat
# 3               4 BHK Flat in Sector 52 Gurgaon          flat
# 4  4 Bedroom House for sale in Sector 7 Gurgaon         house
#
#                    society  price  price_per_sqft    area  \
# 0  signature global solera   0.36          6581.0   547.0
# 1             tulip yellow   1.80         10563.0  1704.0
# 2             tulip violet   1.75          9459.0  1850.0
# 3               ardee city   1.50          9146.0  1640.0
# 4              independent   3.85         14650.0  2628.0
#
#                              areaWithType  bedRoom  bathroom balcony  \
# 0          Carpet area: 547 (50.82 sq.m.)        2         2       2
# 1        Carpet area: 1704 (158.31 sq.m.)        3         3       3
# ...

# %%
df.to_csv('A:/CODES/PROJECTS/appartments/Data/gurgaon/properties.csv', index=False)
